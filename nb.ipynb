# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import gymnasium.utils.seeding as seeding
import matplotlib.pyplot as plt

# %%
class PIDEnv(gym.Env):

    def __init__(self, target=1.0, initial_state=0.0, dt=0.1):
        super(PIDEnv, self).__init__()

        self.K_motor = 0.02  
        self.Ra = 2
        self.Phi = 0.01
        self.Ia = 0.5

        self.target = 2.0

        self.dt = dt

        # self.action_space = spaces.Box(low=np.array(-np.inf*np.ones(3), dtype=np.float32), high=np.array(np.inf*np.ones(3), dtype=np.float32))
        # self.action_space = spaces.Box(low=-np.inf * np.ones(3), high=np.inf * np.ones(3), dtype=np.float32)
        self.action_space = spaces.Box(low=np.array([-10, -10, -10], dtype=np.float32), high=np.array([10, 10, 10], dtype=np.float32))

        self.observation_space = spaces.Box(low=np.array([0.0, 0.0]), high=np.array([2.0, 2.0]), dtype=np.float32)

        self.seed()
        self.state = None
        self.Kp, self.Ki, self.Kd = 1.0, 0.01, 0.01  # Initial PID parameters
        self.integral = 0
        self.prev_error = 0
        # self.states = []
        # self.targets = []
        # self.errors = []
        # self.rewards = []
        # self.Kps = []
        # self.Kis = []
        # self.Kds = []

    def normalize_reward(self, reward, min_reward= -10, max_reward=10):
        clipped_reward = max(min(reward, max_reward), min_reward)
        normalized_reward = (clipped_reward - min_reward) / (max_reward - min_reward) * 2 - 1
        return normalized_reward

    def seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def reset(self, **kwargs):
        self.state = np.random.uniform(low=0.0, high=1.0)
        self.integral = 0
        self.prev_error = 0
        return np.array([self.state, self.target])

    def plotter(self, state, target, error, reward, action, done=False):
        self.states.append(state)
        self.targets.append(target)
        self.errors.append(error)
        self.rewards.append(reward)
        self.Kps.append(action[0])
        self.Kis.append(action[1])
        self.Kds.append(action[2])

        plt.figure(1)
        plt.plot(self.states)
        plt.plot(self.targets)
        plt.title('State and Target')
        plt.ylabel('Value')
        plt.xlabel('Time')
        plt.legend(['State', 'Target'])

        plt.figure(2)
        plt.plot([0]*len(self.errors))
        plt.plot(self.errors)
        plt.title('Error over time')
        plt.ylabel('Value')
        plt.xlabel('Time')
        plt.legend(['Zero', 'Error'])

        # if done:
        #     plt.show()

        return



    def step(self, action):
        # print("Step called with action:", action)
        self.Kp, self.Ki, self.Kd = action

        error = self.target - self.state
        self.integral += error * self.dt
        derivative = (error - self.prev_error) / (self.dt + 1e-5)
        output = self.Kp*error + self.Ki*self.integral + self.Kd*derivative
        self.prev_error = error
        

        V = output

        N = self.K_motor * (V - self.Ia * self.Ra) / self.Phi

        self.state = max(0, min(2, self.state + N * self.dt))

        reward = -np.abs(error)
        if not np.isfinite(reward):
            print(f"Non-finite reward encountered: {reward}")

        reward = self.normalize_reward(reward)

        done = np.abs(error) < 0.001

        # if done:
        #     self.plotter(self.state, self.target, error, reward, action)
        # self.plotter(self.state, self.target, error, reward, action, done)
        # print("Action:", np.trunc(action*100)/100)

        print("error", error)

        if done: 
            print("Done reached")
            print("State:", self.state) 
            print("Target:", self.target)
            print("Error:", error)
            print("Reward:", reward)
            print("Action:", action)


        info = {}
        info["TimeLimit.truncated"] = False

        return np.array([self.state, self.target]), reward, done, False, info

    def render(self, mode='human'):
        pass

    def close(self):
        pass

# %%
import gymnasium
from stable_baselines3 import PPO
from stable_baselines3 import A2C
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy

from pid import PIDEnv

# %%
env = make_vec_env(lambda: PIDEnv(), n_envs=1)

model = PPO("MlpPolicy", env, learning_rate=1e-4, verbose=1)
# model = A2C("MlpPolicy", env, learning_rate=1e-4, verbose=1)

model.learn(total_timesteps=20000)

mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)

print(f"Mean reward: {mean_reward}, Std reward: {std_reward}")
# Out:
# Using cpu device
# error 1.528776699349046
# error 2.0
# error 2.0
# error 1.6865673291747694
# error 0.3211191308814332
# error 0.9958489520081804
# error 2.0
# error 2.0
# error 1.6951177101226653
# error 1.7899714173922008
# error 1.6130696846248305
# error 1.9102734215567665
# error 1.2040217537516265
# error 0.7342276413397961
# error 2.0
# error 0.8630626537205404
# error 0.0
# Done reached
# State: 2
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [ 1.6226478  -1.10209    -0.58793527]
# error 1.6849498637136262
# error 1.0198749983983786
# error 0.6765400669193795
# error 0.6120635039977391
# error 1.0780327572906658
# error 0.42099233772590905
# error 0.0
# Done reached
# State: 2
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [ 0.05537192  0.8752953  -1.8904753 ]
# error 1.851776595136087
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 1.8569295303064766
# error 2.0
# error 0.9761358834872607
# error 0.5018951395446134
# error 1.3073257732634054
# error 1.5045989943293794
# error 1.1989294099755727
# error 2.0
# error 0.39698490031582656
# error 2.0
# error 1.1387439547694373
# error 0.0
# Done reached
# State: 2
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [ 1.5925654  -0.63734525 -0.60393536]
# error 1.5823699399522972
# error 2.0
# error 0.9039413633609126
# error 0.0
# Done reached
# State: 1.7894135379694969
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [ 0.8847391  -2.0488722  -0.09584053]
# error 1.310223106442371
# error 0.0
# Done reached
# State: 1.4891400621014994
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [ 1.4506063  -0.30664274  0.11557376]
# error 1.711320498373596
# error 1.9865278128959367
# error 2.0
# error 2.0
# error 1.976349092303625
# error 2.0
# error 2.0
# error 1.883812516814649
# error 2.0
# error 1.961498271179399
# error 1.6222458298368365
# error 2.0
# error 1.6161016720203518
# error 2.0
# error 1.3876701199661028
# error 1.0941324343569954
# error 1.765987064141294
# error 2.0
# error 2.0
# error 2.0
# error 1.248235769152498
# error 1.707469669546787
# error 2.0
# error 2.0
# error 0.8713339694381261
# error 0.0
# Done reached
# State: 0
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [-0.43244624 -0.53386325  1.4359887 ]
# error 1.897123350102431
# error 2.0
# error 2.0
# error 2.0
# error 1.9339459396620993
# error 1.9688963102295
# error 1.9329974643572383
# error 2.0
# error 2.0
# error 1.58679464532751
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 1.8469673058163338
# error 2.0
# error 1.0650582228930667
# error 2.0
# error 1.443042313473272
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 1.9062762559625372
# error 2.0
# error 2.0
# error 2.0
# error 0.5346704512502187
# error 2.0
# error 0.16476738070212615
# error 0.0
# Done reached
# State: 2
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [-0.54718786  0.7405895  -0.8334301 ]
# error 1.5101523142035136
# error 0.0
# Done reached
# State: 2
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [-5.7472783e-01 -2.5230455e-03 -3.4757297e+00]
# error 1.9098511511687468
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 1.2067980156228924
# error 0.39147821277330297
# error 0.0
# Done reached
# State: 1.3719062436647607
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [-0.2425465   0.10127994  0.57659626]
# error 1.90376939893292
# error 1.2989963513110783
# error 2.0
# error 1.1069466878118681
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 1.393713350401768
# error 1.774903856413561
# error 2.0
# error 2.0
# error 1.9802810456857092
# error 1.9236784388770325
# error 2.0
# error 1.4589713916629203
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 1.6719746216880278
# error 1.4802588080699033
# error 2.0
# error 2.0
# error 1.5738739492541596
# error 2.0
# error 0.0
# Done reached
# State: 1.274023064675522
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 1.7074954157804418
# error 2.0
# error 0.999948913359844
# error 1.014495499163003
# error 1.0877716591546809
# error 2.0
# error 0.36015915357885886
# error 0.0
# Done reached
# State: 0
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [ 0.7749632 -1.7418212  0.4755745]
# error 1.2321958645274522
# error 1.8000972513714095
# error 2.0
# error 2.0
# error 1.8111330908514924
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 1.4656189491289617
# error 0.17892000786965445
# error 0.0
# Done reached
# State: 2
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [ 1.1944809  -0.10582607 -0.86434263]
# error 1.2599033712229395
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 1.4635190842101111
# error 0.0
# Done reached
# State: 2
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [-2.2653925   1.1172774  -0.19345883]
# error 1.407374714677177
# error 2.0
# error 0.9998516973504208
# error 2.0
# error 2.0
# error 1.4562827813544073
# error 0.2690573835304524
# error 0.05149998270350897
# error 0.28858462468568913
# error 0.0
# Done reached
# State: 2
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [ 0.05383979 -1.1572601  -0.7970465 ]
# error 1.234917345504173
# error 0.0
# Done reached
# State: 0.24490826755830208
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [0.52642804 1.2994131  0.6426923 ]
# error 1.6361608947753425
# error 0.0
# Done reached
# State: 1.0228121086283952
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [ 1.8573608  -0.58131397  0.23171353]
# error 1.7627007414076883
# error 1.2087099134144783
# error 1.9730190254298425
# error 1.141333301274563
# error 0.0
# Done reached
# State: 0.3650537123717106
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [0.15308896 0.29791027 0.64457667]
# error 1.8609479533976518
# error 1.387824116178987
# error 1.5824005785615647
# error 2.0
# error 2.0
# error 1.9506647430985744
# error 2.0
# error 1.5675869050872615
# error 0.6774662155049436
# error 2.0
# error 2.0
# error 1.6442269500978224
# error 2.0
# error 1.516695735456694
# error 0.8818880230140989
# error 0.0
# Done reached
# State: 0
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [-1.1145067 -1.0536317  0.8812312]
# error 1.8527252314483391
# error 1.2808066065076718
# error 2.0
# error 0.8863819810704849
# error 2.0
# error 0.0
# Done reached
# State: 0
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [-1.1921662   0.86955047  0.76162654]
# error 1.3424013782894955
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 0.9445158485213165
# error 0.0
# Done reached
# State: 2
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [-0.11245674  0.6242257  -0.17518102]
# error 1.8617195035913199
# error 2.0
# error 1.912308672246556
# error 2.0
# error 2.0
# error 1.4291946293854205
# error 0.5967393443324882
# error 0.0
# Done reached
# State: 2
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [-1.6321981 -1.1529175 -1.7013433]
# error 1.6811162518641747
# error 0.0
# Done reached
# State: 2
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [ 1.9656903 -1.7931362 -1.2560694]
# error 1.4260376597149191
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 1.9175638178759487
# error 1.8532760505691304
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 1.4903495874026977
# error 2.0
# error 0.8865319392990545
# error 1.750185796794775
# error 0.34367508286651116
# error 0.0
# Done reached
# State: 2
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [-0.5305144   1.002989    0.05403263]
# error 1.7765098391111753
# error 2.0
# error 1.8968301458713348
# error 1.8206114856049824
# error 2.0
# error 1.4029355490943876
# error 0.8402030786900441
# error 0.0
# Done reached
# State: 2
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [-0.30974308  0.20553537 -0.3644885 ]
# error 1.4343447521492747
# error 2.0
# error 1.5277427138400113
# error 0.9055714924822698
# error 0.0
# Done reached
# State: 2
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [-0.19261843 -1.1681663  -0.40213007]
# error 1.9848121149120181
# error 0.0
# Done reached
# State: 0.6490231665343245
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [ 1.3201371 -0.958018   0.2803939]
# error 1.0599584383466838
# error 1.3968152533317373
# error 2.0
# error 0.6961134498259867
# error 2.0
# error 2.0
# error 1.8710286917139993
# error 2.0
# error 2.0
# error 1.901955179332573
# error 1.3394409797024207
# error 1.1627432597766112
# error 1.3959999054817194
# error 0.7913162335408577
# error 0.30286064722827
# error 0.0
# Done reached
# State: 2
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [0.00208529 0.9310376  0.21418698]
# error 1.6356080448307606
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 1.9634301901887596
# error 1.6391422311007382
# error 1.837975243777343
# error 2.0
# error 1.2841154450709569
# error 2.0
# error 2.0
# error 2.0
# error 1.1326307284476576
# error 0.4646945972083305
# error 0.13490626217115897
# error 0.19149667433693285
# error 0.0
# Done reached
# State: 1.6579468891687437
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [0
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [ 0.5805322  -0.55738777  0.40511453]
# error 1.2086341683402257
# error 1.2930153634764343
# error 1.8381623818572956
# error 1.0376043940243118
# error 0.0
# Done reached
# State: 2
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [ 0.7952878  -0.32395017 -1.0462753 ]
# error 1.4277181055408268
# error 2.0
# error 0.6850494149981605
# error 1.5791784205143893
# error 1.1065013791431253
# error 2.0
# error 0.9932624174665139
# error 0.7737216271423368
# error 0.12925770423865446
# error 1.4208932171522206
# error 0.019717956439623485
# error 0.0
# Done reached
# State: 2
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [ 0.33352804  0.73143566 -0.9663338 ]
# error 1.958192882678278
# error 2.0
# error 1.7934668448079862
# error 1.9509852195283333
# error 2.0
# error 1.4697166995665834
# error 0.0
# Done reached
# State: 0
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [ 0.5069276 -1.4505341  1.708693 ]
# error 1.9153731628463033
# error 2.0
# error 2.0
# error 1.7928785763928083
# error 1.8191138620334473
# error 1.5104044165940653
# error 1.9914377605073579
# error 2.0
# error 2.0
# error 1.8063495813711623
# error 0.47350300492208053
# error 0.0
# Done reached
# State: 2
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [ 0.79237914 -1.2565545  -1.3371224 ]
# error 1.7357982990508138
# error 2.0
# error 2.0
# error 2.0
# error 1.5832383385542683
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 1.3170216758780628
# error 1.607512463071412
# error 2.0
# error 1.45243218383977
# error 2.0
# error 0.0
# Done reached
# State: 1.507141491163222
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [ 0.76042694 -1.943442   -0.17649648]
# error 1.746478724382539
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 1.704862387388115
# error 1.7561101897307014
# error 2.0
# error 2.0
# error 1.9303334013302966
# error 2.0
# error 1.4688712817796459
# error 2.0
# error 1.6110251498848664
# error 1.227736366022991
# error 1.470424968432805
# error 2.0
# error 2.0
# error 1.7557579218530734
# error 2.0
# error 2.0
# error 2.0
# error 1.1108401457662849
# error 2.0
# error 0.0
# Done reached
# State: 0
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [ 0.9137452  -0.72252315  0.9643883 ]
# error 1.7947220609389278
# error 1.571107451735229
# error 1.3341469682797555
# error 1.058574058134561
# error 1.912003195801585
# error 0.9345052632174731
# error 1.6475061132045359
# error 0.4791480727744162
# error 0.0
# Done reached
# State: 1.006131825186805
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [-0.6553029  -0.6364753   0.68593043]
# error 1.077139926870906
# error 0.0
# Done reached
# State: 0.00978523485419558
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [-0.8676449   0.01618938  0.8312488 ]
# error 1.9503543084259758
# error 2.0
# error 1.9557068383084648
# error 2.0
# error 2.0
# error 1.9093315697239988
# error 2.0
# error 1.757530807316031
# error 1.877046323277765
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 1.4997852221635504
# error 0.0
# Done reached
# State: 2
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [-0.2818958 -0.2072192 -2.0405731]
# error 1.4866194064861766
# error 2.0
# error 1.2042648675203544
# error 1.18720276466826
# error 1.246983227479074
# error 1.2205191539872944
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 1.727443828971768
# error 1.5731844967051702
# error 2.0
# error 2.0
# error 1.7028753666340768
# error 0.9763388378617852
# error 0.0
# Done reached
# State: 1.931271968041943
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [ 0.2560545   0.1595968  -0.02419631]
# error 1.2226746545624911
# error 2.0
# error 0.8187008275416721
# error 0.0
# Done reached
# State: 0.8386651231432365
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [-0.3905818  -0.02109987  0.58612704]
# error 1.3255764776574521
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 1.0151747066158379
# error 0.9415004520548891
# error 1.1120880667866997
# error 0.7928670923061105
# error 0.0
# Done reached
# State: 1.936541474998511
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [-0.90174407  1.496654    0.20059492]
# error 1.5804925693551568
# error 1.589535659877086
# error 1.9491847032349325
# error 1.4962587969791317
# error 2.0
# error 2.0
# error 1.5126025854666816
# error 1.0610714464692244
# error 0.8092760455699581
# error 0.9546360806005301
# error 1.3973353322645383
# error 1.1034867928141132
# error 2.0
# error 0.0
# Done reached
# State: 1.5577155113139818
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [1.7823616  0.5087042  0.11006348]
# error 1.797309278913424
# error 2.0
# error 2.0
# error 1.930115499240089
# error 2.0
# error 2.0
# error 2.0
# error 2.0
# error 1.4402373120493954
# error 2.0
# error 1.601958927700845
# error 2.0
# error 2.0
# error 2.0
# error 1.4381711800348573
# error 0.50774790364706
# error 1.2693183187899846
# error 0.9147722851540214
# error 2.0
# error 2.0
# error 1.2584903311239373
# error 2.0
# error 0.0
# Done reached
# State: 2
# Target: 2.0
# Error: 0.0
# Reward: 0.0
# Action: [2.146614   1.5198783  0.01256312]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 6
#       3 model = PPO("MlpPolicy", env, learning_rate=1e-4, verbose=1)
#       4 # model = A2C("MlpPolicy", env, learning_rate=1e-4, verbose=1)
# ----> 6 model.learn(total_timesteps=20000)
#       8 mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)
#      10 print(f"Mean reward: {mean_reward}, Std reward: {std_reward}")
#
# File c:\Users\ggsin\AppData\Local\pypoetry\Cache\virtualenvs\major-project-iPhJLaak-py3.11\Lib\site-packages\stable_baselines3\ppo\ppo.py:315, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     306 def learn(
#     307     self: SelfPPO,
#     308     total_timesteps: int,
#    (...)
#     313     progress_bar: bool = False,
#     314 ) -> SelfPPO:
# --> 315     return super().learn(
#     316         total_timesteps=total_timesteps,
#     317         callback=callback,
#     318         log_interval=log_interval,
#     319         tb_log_name=tb_log_name,
#     320         reset_num_timesteps=reset_num_timesteps,
#     321         progress_bar=progress_bar,
#     322     )
#
# File c:\Users\ggsin\AppData\Local\pypoetry\Cache\virtualenvs\major-project-iPhJLaak-py3.11\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:277, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     274 assert self.env is not None
#     276 while self.num_timesteps < total_timesteps:
# --> 277     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     279     if not continue_training:
#     280         break
#
# File c:\Users\ggsin\AppData\Local\pypoetry\Cache\virtualenvs\major-project-iPhJLaak-py3.11\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:178, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     175 with th.no_grad():
#     176     # Convert to pytorch tensor or to TensorDict
#     177     obs_tensor = obs_as_tensor(self._last_obs, self.device)
# --> 178     actions, values, log_probs = self.policy(obs_tensor)
#     179 actions = actions.cpu().numpy()
#     181 # Rescale and perform action
#
# File c:\Users\ggsin\AppData\Local\pypoetry\Cache\virtualenvs\major-project-iPhJLaak-py3.11\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ggsin\AppData\Local\pypoetry\Cache\virtualenvs\major-project-iPhJLaak-py3.11\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\ggsin\AppData\Local\pypoetry\Cache\virtualenvs\major-project-iPhJLaak-py3.11\Lib\site-packages\stable_baselines3\common\policies.py:652, in ActorCriticPolicy.forward(self, obs, deterministic)
#     650 # Evaluate the values for the given observations
#     651 values = self.value_net(latent_vf)
# --> 652 distribution = self._get_action_dist_from_latent(latent_pi)
#     653 actions = distribution.get_actions(deterministic=deterministic)
#     654 log_prob = distribution.log_prob(actions)
#
# File c:\Users\ggsin\AppData\Local\pypoetry\Cache\virtualenvs\major-project-iPhJLaak-py3.11\Lib\site-packages\stable_baselines3\common\policies.py:692, in ActorCriticPolicy._get_action_dist_from_latent(self, latent_pi)
#     689 mean_actions = self.action_net(latent_pi)
#     691 if isinstance(self.action_dist, DiagGaussianDistribution):
# --> 692     return self.action_dist.proba_distribution(mean_actions, self.log_std)
#     693 elif isinstance(self.action_dist, CategoricalDistribution):
#     694     # Here mean_actions are the logits before the softmax
#     695     return self.action_dist.proba_distribution(action_logits=mean_actions)
#
# File c:\Users\ggsin\AppData\Local\pypoetry\Cache\virtualenvs\major-project-iPhJLaak-py3.11\Lib\site-packages\stable_baselines3\common\distributions.py:164, in DiagGaussianDistribution.proba_distribution(self, mean_actions, log_std)
#     156 """
#     157 Create the distribution given its parameters (mean, std)
#     158
#    (...)
#     161 :return:
#     162 """
#     163 action_std = th.ones_like(mean_actions) * log_std.exp()
# --> 164 self.distribution = Normal(mean_actions, action_std)
#     165 return self
#
# File c:\Users\ggsin\AppData\Local\pypoetry\Cache\virtualenvs\major-project-iPhJLaak-py3.11\Lib\site-packages\torch\distributions\normal.py:56, in Normal.__init__(self, loc, scale, validate_args)
#      54 else:
#      55     batch_shape = self.loc.size()
# ---> 56 super().__init__(batch_shape, validate_args=validate_args)
#
# File c:\Users\ggsin\AppData\Local\pypoetry\Cache\virtualenvs\major-project-iPhJLaak-py3.11\Lib\site-packages\torch\distributions\distribution.py:67, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      65         value = getattr(self, param)
#      66         valid = constraint.check(value)
# ---> 67         if not valid.all():
#      68             raise ValueError(
#      69                 f"Expected parameter {param} "
#      70                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#    (...)
#      73                 f"but found invalid values:\n{value}"
#      74             )
#      75 super().__init__()
#
# KeyboardInterrupt:
